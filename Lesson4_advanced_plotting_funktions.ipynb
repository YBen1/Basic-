# %% [markdown]
# <a href="https://colab.research.google.com/github/YBen1/PandaPower_Basics/blob/main/Lesson4_advanced_plotting_funktions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lesson 4

# %%
# !pip install pandapower
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.0 MB 22.4 MB/s
# ...
#   Created wheel for pandapower: filename=pandapower-2.9.0-py3-none-any.whl size=5931108 sha256=2fce0d90ad582427ad5c34af03ad7ab8a565f0af35a00768a0ffab648da705b2
#   Stored in directory: /root/.cache/pip/wheels/94/44/e3/be45d434be4b2427df371bf379756058ae2485e721c8acca2a
# Successfully built pandapower
# ...

# %%
# !pip install pytest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandapower.test
import pandapower as pp
import pandapower.networks as nw
import pandapower.topology
import pandapower.plotting as plot
import matplotlib.pyplot as plt
import seaborn
colors = seaborn.color_palette()
import pandapower.converter
import pandapower.estimation

# %%
net = nw.mv_oberrhein()

# %%
bc = plot.create_bus_collection(net, buses=net.bus.index, color = colors[0], size =80, zorder =1)
lc = plot.create_line_collection(net, lines=net.line.index, color = 'grey', zorder = 2)
plot.draw_collections([lc,bc])
plt.show()
# Out:
# WARNING:pandapower.plotting.plotting_toolbox:The number of given colors (1) is smaller than the number of nodes (179) to draw! The colors will be repeated to fit.

# %%
simple_plotly(net)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pf_res_plotly(net)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
