# %% [markdown]
# <a href="https://colab.research.google.com/github/YBen1/PandaPower_Basics/blob/main/Lesson5_topology_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lesson 5
# we try to finde the shortes connection between busses

# %%
# !pip install pandapower
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pytest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandapower.test
import pandapower as pp
import pandapower.networks as nw
import pandapower.topology as top
import pandapower.plotting as plot
import matplotlib.pyplot as plt
import pandapower.converter
import pandapower.estimation
import networkx as nx

# %%
net = nw.simple_mv_open_ring_net()
mg = top.create_nxgraph(net)

# %% [markdown]
# ![nx_shortest_path.png](data:image/png;base64,...)

# %%
shortest = nx.shortest_path(mg,0,5)

# %%
print(shortest)
# Out:
# [0, 1, 6, 5]
