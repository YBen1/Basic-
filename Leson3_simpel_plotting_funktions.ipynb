# %% [markdown]
# <a href="https://colab.research.google.com/github/YBen1/PandaPower_Basics/blob/main/Leson3_simpel_plotting_funktions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lesson one

# %%
# !pip install pandapower
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.0 MB 22.8 MB/s
# ...
#   Created wheel for pandapower: filename=pandapower-2.9.0-py3-none-any.whl size=5931108 sha256=3a49cf9e69246482c015739850f7482d0ade10b2c042d4da86a24fc3f0b48cc8
#   Stored in directory: /root/.cache/pip/wheels/94/44/e3/be45d434be4b2427df371bf379756058ae2485e721c8acca2a
# Successfully built pandapower
# ...

# %%
# !pip install pytest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandapower.test
import pandapower as pp
import pandapower.networks as nw
import pandapower.topology
from pandapower.plotting import simple_plot, simple_plotly, pf_res_plotly
import pandapower.converter
import pandapower.estimation

# %%
net = nw.mv_oberrhein()

# %%
simple_plot(net)

# %%
simple_plotly(net)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pf_res_plotly(net)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
